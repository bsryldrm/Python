# %%
x,y,z = 5, 10, 15

# %%
x, y = y, x      #değişkenler arası atama

# %%
x,y,z
# Out:
# (10, 5, 15)

# %%
x += 5

# %%
x
# Out:
# 15

# %%
x -= 5
x
# Out:
# 10

# %%
x *= 5
x
# Out:
# 50

# %%
x %= 5

# %%
x
# Out:
# 0

# %%
y //= 5

# %%
y
# Out:
# 1

# %%
y **= z

# %%
z
# Out:
# 15

# %%
values = 1, 2,3

# %%
type(values)
# Out:
# tuple

# %%
x, y,z = values     #tupple değerlerini değişknlere atama

# %%
x, y,z
# Out:
# (1, 2, 3)

# %%
values2 = 5, 4, 8

# %%
b, y = values2        #tuple içindeki değer ile tanımlanan değiişke sayısı uyuşmuyor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a53159d81600> in <cell line: 1>()
# ----> 1 b, y = values2
#
# ValueError: too many values to unpack (expected 2)

# %%
values3 = 5, 4, 8, 9, 6, 3

# %%
m, c, *h = values3       #fazla diğer elemanlar h  liste olarak atanır

# %%
m
# Out:
# 5

# %%
c
# Out:
# 4

# %%
h
# Out:
# [8, 9, 6, 3]

# %%
m, c, *h
# Out:
# (5, 4, 8, 9, 6, 3)

# %%
type(h)
# Out:
# list

# %%
h[3]
# Out:
# 3

# %%
x, y, z = 2, 5, 107

numbers = 1, 5, 7, 10, 6

# %%
#kullanıcıdan aldığınız 2 sayının çarpımı ile x,y,z  toplamının farkı nedir?

a = int(input('1.sayı:'))
b = int(input('2.sayı:'))

result = (a*b) - (x+y+z)
result
# Out:
# 1.sayı:8
# 2.sayı:9
# -42

# %%
# y'nin x'e kalansız bölümünü hesaplayınız

result = y // x
result
# Out:
# 2

# %%
# (x+y+z) toplamının mod 3 ü nedir?

toplam = (x+y+z)
result = toplam % 3
result
# Out:
# 0

# %%
# y nin x. kuvvetini hesaplayalım

result = y ** x
result
# Out:
# 25

# %%
#x, *y, z = numbers işlemine göre z nin küpü kkaçtır?
x, *y, z = numbers
print(z)
result = z**3
result
# Out:
# 6
# 216

# %%
#x, *y, z = numbers işlemine göre y nin toplamı nedir?

x, *y, z = numbers
print(y)
result = y[0] + y[1] + y[2]
result
# Out:
# [5, 7, 10]
# 22
