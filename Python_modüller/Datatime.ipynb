# %%
import datetime

# %%
result= dir(datetime)

# %%
print(result)
# Out:
# ['MAXYEAR', 'MINYEAR', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'sys', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
from datetime import datetime

# %%
tarih = datetime.now()
tarih
# Out:
# datetime.datetime(2024, 1, 24, 9, 52, 36, 286809)

# %%
tarih = datetime.today()
tarih
# Out:
# datetime.datetime(2024, 1, 24, 9, 52, 38, 870378)

# %%
tarih.year
# Out:
# 2024

# %%
tarih.month
# Out:
# 1

# %%
result = datetime.ctime(tarih)
print(result)
# Out:
# Wed Jan 24 09:52:38 2024

# %%
result = datetime.strftime(tarih,"%Y")
print(result)
# Out:
# 2024

# %%
result = datetime.strftime(tarih,"%X")
print(result)
# Out:
# 09:52:38

# %%
result = datetime.strftime(tarih,"%d")
print(result)
# Out:
# 24

# %%
result = datetime.strftime(tarih,"%A")
print(result)
# Out:
# Wednesday

# %%
result = datetime.strftime(tarih,"%B")
print(result)
# Out:
# January

# %%
result = datetime.strftime(tarih,"%Y %B %A")
print(result)
# Out:
# 2024 January Wednesday

# %%
t = '15 april 2022 hour 10:56:45'
result = datetime.strptime(t, '%d %B %Y hour %H:%M:%S')
result = result.year
result
# Out:
# 2022
