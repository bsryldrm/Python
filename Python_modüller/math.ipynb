# %% [markdown]
# #yöntem 1

# %%
import math

value = dir(math)
print(value)
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
value = help(math.factorial)
# Out:
# Help on built-in function factorial in module math:
#
# factorial(x, /)
#     Find x!.
#
#     Raise a ValueError if x is negative or non-integral.

# %%
value = math.sqrt(49)
print(value)
# Out:
# 7.0

# %%
value = math.factorial(5)
print(value)
# Out:
# 120

# %%
value = math.floor(5.9)  #kendisinden küçük en büyük tam sayıya yuvarlar
print(value)
# Out:
# 5

# %%
value = math.ceil(5.9)  #kendisinden büyük en küçük tam sayıya yuvarlar
print(value)
# Out:
# 6

# %% [markdown]
# #yöntem 2
#
#
# *   kütüphanedeki tüm metotları yüklediğimiz için math. diyip fonksiyonlara te tek ulaşmamıza gerek yok

# %%
from math import *

value = factorial(5)
print(value)

value = sqrt(9)
print(value)
