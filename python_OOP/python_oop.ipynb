# %%
#class

class Person:

  #class attributes
  address = 'no information'

  #constructor (yapıcı method)
  def __init__(self, name, year):

    #object attributes
    self.name = name
    self.year = year
    print('init metodu çalıştı.')

  #methods


#objecti instance

p1 = Person('ali', 1999)

print(p1)
# Out:
# init metodu çalıştı.
# ...

# %%
print(f'p1 name: {p1.name}, year :{p1.year} address: {p1.address} ')
# Out:
# p1 name: ali, year :1999 address: no information

# %%
#uptading

p1.name ='Ahmet'

# %%
print(f'p1 name: {p1.name}, year :{p1.year} address: {p1.address} ')
# Out:
# p1 name: Ahmet, year :1999 address: no information

# %% [markdown]
# ##metotlar

# %%
#class

class Person:

  #class attributes
  address = 'no information'

  #constructor (yapıcı method)
  def __init__(self, name, year):

    #object attributes
    self.name = name
    self.year = year
    print('init metodu çalıştı.')

  # instance methods
  def intro(self):
    print('Hello There. I am ' + self.name )
  def calculateAge(self):
    return 2020 - self.year
#objecti instance

p1 = Person('ali', 1999)

p1.intro()
# Out:
# init metodu çalıştı.
# Hello There. I am ali

# %%
print(f"adım: {p1.name} ve yaşım: {p1.calculateAge()}")
# Out:
# adım: ali ve yaşım: 21

# %%
class Circle:
  #Class object attribute
  pi = 3.14

  def __init__(self, yaricap = 1) :
    self.yaricap = yaricap

  def cevre_hesapla(self):
    return 2 * self.pi + self.yaricap

  def alan_hesapla(self):
    return self.pi * (self.yaricap**2)

c1 = Circle()  # yarı çap = 1
c2 = Circle(5)

# %%
print(f'c1: alan = {c1.alan_hesapla()}, cevre = {c1.cevre_hesapla()}')
print(f'c2: alan = {c2.alan_hesapla()}, cevre = {c2.cevre_hesapla()}')
# Out:
# c1: alan = 3.14, cevre = 7.28
# c2: alan = 78.5, cevre = 11.280000000000001

# %% [markdown]
# ##inheritance ( kalıtım )

# %%
#classların birbirinden miras alma durumu!
class Person():
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname
    print('Person Created')

class Student(Person):
  def __init__(self,  fname, lname):
    Person.__init__(self, fname, lname)
    print('Student Created')

p1 = Person('Deniz', 'Turan')
# Out:
# Person Created

# %%
s1 = Student('Hilal', 'Yıldız')
# Out:
# Person Created
# Student Created

# %%
print(p1.firstname + ' '+ p1.lastname)
print(s1.firstname + ' '+ s1.lastname)
# Out:
# Deniz Turan
# Hilal Yıldız

# %%
class Person():
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname
    print('Person Created')

  def who_am_i(self):
    print('I am a person')

  def eat(self):
    print('I am eating')

class Student(Person):
  def __init__(self,  fname, lname):
    Person.__init__(self, fname, lname)
    print('Student Created')
  #override
  def who_am_i(self):
    print('I am a student')

# %%
s1 = Student('Hilal', 'Yıldız')
# Out:
# Person Created
# Student Created

# %%
#aynı sınıftaki fonksiyon temel sınıftaki fonksiyondan önceliklidir
# bu yüzden, who_am_i() fonk. çalıştırdığımızda 'I am a person' değil 'I am a student' yazdı.

s1.who_am_i()
# Out:
# I am a student

# %%
class Person():
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname
    print('Person Created')

  def who_am_i(self):
    print('I am a person')

  def eat(self):
    print('I am eating')

class Student(Person):
  def __init__(self,  fname, lname, number):
    Person.__init__(self, fname, lname)
    self.studentnumber = number
    print('Student Created')
  #override
  def who_am_i(self):
    print('I am a student')

# %%
s1 = Student('Hilal', 'Yıldız',1071)
# Out:
# Person Created
# Student Created

# %%
print(s1.firstname + ' '+ s1.lastname + ' ' + str(s1.studentnumber))
# Out:
# Hilal Yıldız 1071

# %%
class Person():
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname
    print('Person Created')

  def who_am_i(self):
    print('I am a person')

  def eat(self):
    print('I am eating')

class Teacher(Person):
  def __init__(self, fname, lname, branch):
    super().__init__(fname, lname)
    self.branch = branch

  def who_am_i(self):
    print(f'I am a {self.branch} Teacher')

t1 = Teacher('Serkan', 'Yılmaz', 'matematik')
# Out:
# Person Created

# %%
t1.who_am_i()
# Out:
# I am a matematik Teacher

# %% [markdown]
# ## özel metotlar

# %%
myList = [1,2,3]
myString = 'my string'

# %%
class Movie():
  def __init__(self, title, director,duration):
    self.title = title
    self.director = director
    self.duration = duration
    print('movie objesi oluşturuldu.')

m = Movie('film adı', 'yönetmen adı', 'filmin süresi')
# Out:
# movie objesi oluşturuldu.

# %%
print(myList)
# Out:
# [1, 2, 3]

# %%
print(m)

# %%
class Movie():
  def __init__(self, title, director,duration):
    self.title = title
    self.director = director
    self.duration = duration
    print('movie objesi oluşturuldu.')
  def __str__(self):
    return f"{self.title} by {self.director}"

m = Movie('film adı', 'yönetmen adı', 'filmin süresi')
# Out:
# movie objesi oluşturuldu.

# %%
print(str(myList))
# Out:
# [1, 2, 3]

# %%
print(str(m))
# Out:
# film adı by yönetmen adı

# %%
class Movie():
  def __init__(self, title, director,duration):
    self.title = title
    self.director = director
    self.duration = duration
    print('movie objesi oluşturuldu.')

  def __str__(self):
    return f"{self.title} by {self.director}"

  def __len__(self):
    return self.duration

m = Movie('film adı', 'yönetmen adı', 120)
# Out:
# movie objesi oluşturuldu.

# %%
print(len(myList))
# Out:
# 3

# %%
print(len(m))
# Out:
# 120

# %%
#obje sil
del m

# %%
print(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c384c0c7b6c7> in <cell line: 1>()
# ----> 1 print(m)
#
# NameError: name 'm' is not defined

# %%
class Movie():
  def __init__(self, title, director,duration):
    self.title = title
    self.director = director
    self.duration = duration
    print('movie objesi oluşturuldu.')

  def __str__(self):
    return f"{self.title} by {self.director}"

  def __len__(self):
    return self.duration

  def __del__(self):
    print('film objesi silindi.')

m = Movie('film adı', 'yönetmen adı', 120)
# Out:
# movie objesi oluşturuldu.

# %%
#obje sil
del m
