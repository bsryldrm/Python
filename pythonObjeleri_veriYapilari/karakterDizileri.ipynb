# %%
website = "https://www.btkakademi.gov.tr"
course = "Sıfırdan İleri Seviye Python Programlama"

# %%
len(course)
# Out:
# 8

# %%
website[8:11]
# Out:
# 'www'

# %%
website[-2:]
# Out:
# 'tr'

# %%
course[:15]
# Out:
# 'Sıfırdan İleri '

# %%
course[-15:]
# Out:
# 'hon Programlama'

# %%
course[::-1]   #değişkendeki ifadeyi baştan sona ters bir şekilde yazmak.
# Out:
# 'amalmargorP nohtyP eyiveS irelİ nadrıfıS'

# %%
name , surname , age , job = "Kaan Ali", "Yıldırım" , "21" , "Mühendis"

# %%
print(f"Benim adım {name} {surname}, {age} yaşındayım. Mesleğim {job}.")
# Out:
# Benim adım Kaan Ali Yıldırım, 21 yaşındayım. Mesleğim Mühendis.

# %%
result = "Hello world"

# %%
result  * 3  #string ifadeleri birden çok yazdırmak istersek..
# Out:
# 'Hello worldHello worldHello world'

# %%
""
