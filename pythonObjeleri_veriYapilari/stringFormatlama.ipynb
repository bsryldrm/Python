# %%
name = "Hilal"
surname = "Yıldız"

# %%
print("benim adım {} {}.".format(name, surname))
# Out:
# benim adım Hilal Yıldız.

# %%
print("benim adım {s} {n}.".format(n = name, s = surname))
# Out:
# benim adım Yıldız Hilal.

# %%
print("benim adım {1} {0}.".format(name, surname))
# Out:
# benim adım Yıldız Hilal.

# %%
print(f"benim adım {name} {surname}.")
# Out:
# benim adım Hilal Yıldız.
