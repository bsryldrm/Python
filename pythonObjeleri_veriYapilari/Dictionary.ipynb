# %%
sehirler = ["Kocaeli", "İstanbul"]
plakalar = [41,34]

# %%
print(plakalar[sehirler.index("İstanbul")])
# Out:
# 34

# %%
plakalar = {"Kocaeli" : 41, "İstanbul" : 34}

# %%
print(plakalar["Kocaeli"])
print(plakalar["İstanbul"])
# Out:
# 41
# 34

# %%
plakalar["Ankara"] = 6    #yeni bilgi ekle

# %%
print(plakalar)
# Out:
# {'Kocaeli': 41, 'İstanbul': 34, 'Ankara': 6}

# %%
plakalar["Kocaeli"] = 'new value'   #var olan bilgiyi değiştir

# %%
print(plakalar)
# Out:
# {'Kocaeli': 'new value', 'İstanbul': 34, 'Ankara': 6}

# %%
users = {
    'busrayıldırım' : {
        'age' : 23,
        'email' :"busray.1918@gmail.com",
        'addres' : 'Sivas'
    } ,

    'fatihyıldırım' : {
        'age' : 10,
        'email' :"mfyıldırım@gmail.com",
        'addres' : 'İstanbul'
    }
}

# %%
users['busrayıldırım']
# Out:
# {'age': 23, 'email': 'busray.1918@gmail.com', 'addres': 'Sivas'}

# %%
users['busrayıldırım']['age']
# Out:
# 23
