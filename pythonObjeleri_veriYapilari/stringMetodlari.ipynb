# %%
metin = "Hello everyone. How are you?"

# %%
metin.upper()
# Out:
# 'HELLO EVERYONE. HOW ARE YOU?'

# %%
metin.lower()
# Out:
# 'hello everyone. how are you?'

# %%
metin.title()
# Out:
# 'Hello Everyone. How Are You?'

# %%
metin.capitalize()
# Out:
# ' hello everyone. how are you?'

# %%
metin
# Out:
# 'Hello everyone. How are you?'

# %%
metin.strip()
# Out:
# 'Hello everyone. How are you?'

# %%
metin.split()
# Out:
# ['Hello', 'everyone.', 'How', 'are', 'you?']

# %%
metin.split(".")
# Out:
# ['Hello everyone', ' How are you?']

# %%
index = metin.find("are")    #are stringin kaçıncı indexden itibaren bulunduğu bilgisini verir.
print(index)
# Out:
# 20

# %%
metin.startswith("H")        #değişken içerisindeki ifadenin hangi harf ile başladiğının sorgusunu yapar ve bool değer döndürür.
# Out:
# True

# %%
metin.endswith("H")         #değişken içerisindeki ifadenin hangi harf ile bittiğinin sorgusunu yapar ve bool değer döndürür.
# Out:
# False

# %%
metin.replace("Hello","Good bye")
# Out:
# 'Good bye everyone. How are you?'

# %%
metin.replace("Hello","Good bye").replace("How are", "See")
# Out:
# 'Good bye everyone. See you?'

# %%
metin.center(100,"*")
# Out:
# '************************************Hello everyone. How are you?************************************'
