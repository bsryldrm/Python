# %%
numbers = [1, 10, 5, 16, 4, 9, 10]
letters = [ "y", "b", "m", "s", "h", "t", "c"]

# %%
min(numbers)
# Out:
# 1

# %%
max(numbers)
# Out:
# 16

# %%
min(letters)
# Out:
# 'b'

# %%
max(letters)
# Out:
# 'y'

# %%
numbers[3:6]   # 3.indexten 6. indexe kadar yazar
# Out:
# [16, 4, 9]

# %%
numbers[:3]   # baştan 3. ü indexe kadar yazar
# Out:
# [1, 10, 5]

# %%
numbers[4:]     # 4. indeten sona kadar yazar
# Out:
# [4, 9, 10]

# %%
numbers
# Out:
# [1, 10, 5, 16, 4, 9, 10]

# %%
numbers[4] = 40     # 4. indexteki elemana 40 değerini atar
numbers
# Out:
# [1, 10, 5, 16, 40, 9, 10]

# %%
numbers.append(49)
numbers
# Out:
# [1, 10, 5, 16, 40, 9, 10, 49]

# %%
numbers.append(59)    #append metodu listenin sonuna ekler

# %%
numbers
# Out:
# [1, 10, 5, 16, 40, 9, 10, 49, 59]

# %%
#insert metodu ise listenin istediğimiz indexine ekleme yapar ve indexte bulunan önceki değeri sona doğru kaydırır.
numbers.insert(3, 58)
numbers
# Out:
# [1, 10, 5, 58, 16, 40, 9, 10, 49, 59]

# %%
numbers.sort()    #küçükten büyüğe sıralanır
numbers
# Out:
# [1, 5, 9, 10, 10, 16, 40, 49, 58, 59]

# %%
letters.sort()
letters
# Out:
# ['b', 'c', 'h', 'm', 's', 't', 'y']

# %%
numbers.reverse()    #listeyi tersine çevirir
numbers
# Out:
# [59, 58, 49, 40, 16, 10, 10, 9, 5, 1]

# %%
numbers.count(10)    #liste içerisnde belirli elemandan kaç tane olduğunun bilgisini döndürür.
# Out:
# 2

# %%
numbers.clear()   #listedeki elemanların hepsini siler. boş bir liste döndürür
numbers
# Out:
# []

# %%
del(numbers)      #listeyi komple siler

# %%
numbers           # slidiği için tekrar çalıştırdığımızda nameerror döndürür.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-6a54518a0c2c> in <cell line: 1>()
# ----> 1 numbers
#
# NameError: name 'numbers' is not defined
