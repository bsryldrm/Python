# %%
marka = ["Bmw", "Mercedes", "Opel", "Mazda"]

# %%
len(marka)   #liste kaç elemanlı
# Out:
# 4

# %%
marka[0]
# Out:
# 'Bmw'

# %%
marka[3]
# Out:
# 'Mazda'

# %%
marka[3] ="Toyota"   #mazda değerini toyota ile değiştir
marka
# Out:
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']

# %%
#mercedes listenin bie elemanımıdır?
result = "Mercedes" in marka
result
# Out:
# True

# %%
#listenin ilk 3 elemanı
marka[:3]
# Out:
# ['Bmw', 'Mercedes', 'Opel']

# %%
marka[-2:] = "Toyota " ,"Renault"   #son 2 elemanına başka değerler atın
marka
# Out:
# ['Bmw', 'Mercedes', 'Toyota ', 'Renault']

# %%
#liste üzerine eleman ekle
result = marka + ["Audi" , "Togg"]
result
# Out:
# ['Bmw', 'Mercedes', 'Toyota ', 'Renault', 'Audi', 'Togg']

# %%
#listenin son elemanını sil
del marka[-1]
marka
# Out:
# ['Bmw', 'Mercedes', 'Toyota ']

# %%
# Aşağıdaki verileri bir liste içinde saklayınız.
#  studentA: Yiğit Bilgi 2010, (70,80,70)
#  studentB: Sena Turan 1999, (80,80,70)
#  studentC: Ahmet Turan 1998, (80,70, 90)

studentA = ["Yiğit", "Bilgi", 2010, [70,80,70]]
studentB = ["Sena", "Turan", 1999, [80,80,70]]
studentC = ["Ahmet", "Turan", 1998, [80,70,90]]

notBilgisi = f"{studentA[0]} {studentA[1]}, {2023-studentA[2]} yaşında ve not ortalaması {(studentA[3][0] + studentA[3][1] + studentA[3][2]) / 3}"
print(notBilgisi)
# Out:
# Yiğit Bilgi, 13 yaşında ve not ortalaması 73.33333333333333
