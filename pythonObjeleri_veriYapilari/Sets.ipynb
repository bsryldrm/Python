# %%
fruits = {"orange", "apple", "banana"}

# %%
print(fruits)
#print(fruits[0])   indexlenemez
# Out:
# {'banana', 'apple', 'orange'}

# %%
fruits.add("cherry")

# %%
fruits.update(["mango", "grape", "apple"])

# %%
fruits   #apple var olduğu için 2. defa eklemdi
# Out:
# {'apple', 'banana', 'cherry', 'grape', 'mango', 'orange'}

# %%
fruits.remove("mango")

# %%
fruits
# Out:
# {'apple', 'banana', 'cherry', 'grape', 'orange'}

# %%
fruits.discard("apple")

# %%
fruits
# Out:
# {'banana', 'cherry', 'grape', 'orange'}

# %%
fruits.pop()  #herhangi bir elemanı siler çünkü liste sıralı değil
# Out:
# 'banana'

# %%
fruits
# Out:
# {'cherry', 'orange'}
