# %%
list = [1, 2, 3]

# %%
tuple = (1, "iki", 3)

# %%
list[2]
# Out:
# 3

# %%
tuple[2]
# Out:
# 3

# %%
list[2] ="busray"

# %%
list
# Out:
# [1, 2, 'busray']

# %%
tuple[2] = "busray"     #tuple da değişiklik yapamayız ama listelerde yaparız.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e1f6ed64a9e9> in <cell line: 1>()
# ----> 1 tuple[2] = "busray"
#
# TypeError: 'tuple' object does not support item assignment

# %%
names = ("beyza" ,"esra", "lina")

# %%
tuple + names
# Out:
# (1, 'iki', 3, 'beyza', 'esra', 'lina')
