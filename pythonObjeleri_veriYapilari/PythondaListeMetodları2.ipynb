# %%
names = ["İlayda", "Büşra", "Zeynep", "Fatih"]
years = [2001, 1999, 2011, 2013]

# %%
names.append("Cenk")      #liste sonuna ekleme yapar
names
# Out:
# ['İlayda', 'Büşra', 'Zeynep', 'Fatih', 'Cenk']

# %%
names.insert(0, "Sena")    #istenilen indexe ekleme yapar
names
# Out:
# ['Sena', 'İlayda', 'Büşra', 'Zeynep', 'Fatih', 'Cenk']

# %%
names.remove("Fatih")    #fatih listeden siler

# %%
names
# Out:
# ['Sena', 'İlayda', 'Büşra', 'Zeynep', 'Cenk']

# %%
# büşra ismi kaçıncı indexte ?
index = names.index("Büşra")
index
# Out:
# 2

# %%
#ilayda listenin bir elemanı mı?

result = "İlayda"  in names
result
# Out:
# True

# %%
names.sort()
names
# Out:
# ['Büşra', 'Cenk', 'Sena', 'Zeynep', 'İlayda']

# %%
names.reverse()
names
# Out:
# ['İlayda', 'Zeynep', 'Sena', 'Cenk', 'Büşra']

# %%
years.sort()            #years listesini rakamsal büyüklüğe göre sıralayınız
years.reverse()
years
# Out:
# [2013, 2011, 2001, 1999]

# %%
#str ="Chevrolet, Togg"  karakter dizisini liste çeviriniz
str ="Chevrolet, Togg"
result = str.split(",")
result
# Out:
# ['Chevrolet', ' Togg']

# %%
max(years)
# Out:
# 2013

# %%
min(years)
# Out:
# 1999

# %%
years.clear()

# %%
years
# Out:
# []

# %%
markalar =[]

# %%
markalar.append(input("bir araba markası girirniz:"))
# Out:
# bir araba markası girirniz:opel

# %%
markalar
# Out:
# ['togg', 'opel']
