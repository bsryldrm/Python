# %%
result = " Hello world ".strip( ) #değişken içerisindeki boşluk ifadelerini siler.

#result = " Hello world ".lstrip( )    #sol taraftaki istenmeyen karakterleri siler
#result = " Hello world ".rstrip( )    #sağ taraftaki istenmeyen karakterleri siler

print(result)
# Out:
# Hello world

# %%
tane = result.count("e")
tane
# Out:
# 1

# %%
result.upper()    #tüm karakterleri büyük harfe dönüştürür ve yazar
# Out:
# 'HELLO WORLD'

# %%
result.lower()    #tüm karakterleri küçük harfe dönüştürür ve yazar
# Out:
# 'hello world'

# %%
result.title()    #sadece baş harfleri büyük yazar
# Out:
# 'Hello World'

# %%
result.startswith("H")     #değişkenin ? karakeri ile başladığını sorgular.
# Out:
# True

# %%
result.endswith("o")      #değişkenin ? karakeri ile bittiğini sorgular.
# Out:
# False

# %%
result.find('el')      #stringin kaçıncı indexten başladığının bilgisini verir
# Out:
# 1

# %%
result.isalpha()
# Out:
# False

# %%
result.center(50,'*')
# Out:
# '*******************Hello world********************'

# %%
result.ljust(50,'*')
# Out:
# 'Hello world***************************************'

# %%
result.rjust(50,'*')
# Out:
# '***************************************Hello world'

# %%
result.replace(' ', '*')
# Out:
# 'Hello*world'

# %%
result.replace('world', 'There')
# Out:
# 'Hello There'
